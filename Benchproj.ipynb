# %% [markdown]
# <a href="https://colab.research.google.com/github/gwegman7630/BIOI-500-Benchmarking-Project-2025/blob/main/Benchproj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

raw = pd.read_csv('/home/BPPrunedData.csv')
print(raw)

ex1 = raw[raw['Experiment']==1]
ex2 = raw[raw['Experiment']==2]
ex3 = raw[raw['Experiment']==3]

dvs = ['LGA90', 'misassemblies', 'contigs', '16Sident']
sns.set(font_scale=1.5)
sns.set_theme(style='whitegrid', font='Times New Roman' )
############################################ exp1 LGA90
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex1,
    x = "Tool",
    y = dvs[0],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Quality on LGA90')
plt.axhline(0, color="black")
plt.show
############################################# exp1 Misassem.
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex1,
    x = "Tool",
    y = dvs[1],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Quality on Misassemblies')
plt.axhline(0, color="black")
plt.show
############################################## exp1 Contig#
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex1,
    x = "Tool",
    y = dvs[2],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Quality on Contig Number')
plt.axhline(0, color="black")
plt.show
############################################## exp1 16S
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex1,
    x = "Tool",
    y = dvs[3],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Quality on 16S Region')
plt.axhline(0, color="black")
plt.show
############################################## exp1 runtime
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex1,
    x = "Tool",
    y = dvs[3],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange','red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Quality on Runtime')
plt.axhline(0, color="black")
plt.show
############################################## exp1 Memory
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex1,
    x = "Tool",
    y = dvs[4],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange','red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Quality on Memory Usage')
plt.axhline(0, color="black")
plt.show
############################################## exp2 LGA90
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex2,
    x = "Tool",
    y = dvs[0],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Coverage on LGA90')
plt.axhline(0, color="black")
plt.show
############################################### exp2 misassem.
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex2,
    x = "Tool",
    y = dvs[1],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Coverage on Misassemblies')
plt.axhline(0, color="black")
plt.show
############################################### exp2 Contig #
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex2,
    x = "Tool",
    y = dvs[2],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Coverage on Number of Contigs')
plt.axhline(0, color="black")
plt.show
################################################## exp2 16S
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex2,
    x = "Tool",
    y = dvs[3],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange', 'red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Coverage on 16S Region')
plt.axhline(0, color="black")
plt.show
################################################### exp2 runtime
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex2,
    x = "Tool",
    y = dvs[4],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange','red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Coverage on Runtime')
plt.axhline(0, color="black")
plt.show
##################################################### exp2 memory
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex2,
    x = "Tool",
    y = dvs[5],
    jitter = True,
    hue = 'Scale',
    palette = ['green', 'orange','red'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of Read Coverage on Memory Usage')
plt.axhline(0, color="black")
plt.show
##################################################### exp3 LGA90
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex3,
    x = "Tool",
    y = dvs[0],
    jitter = True,
    hue = 'Scale',
    palette = ['blue', 'orange'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of ONT Reads on LGA90')
plt.axhline(0, color="black")
plt.show
##################################################### exp3 Misassemb
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex3,
    x = "Tool",
    y = dvs[1],
    jitter = True,
    hue = 'Scale',
    palette = ['blue', 'orange'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of ONT Reads on Misassemblies')
plt.axhline(0, color="black")
plt.show
#####################################################exp3 Contig#
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex3,
    x = "Tool",
    y = dvs[2],
    jitter = True,
    hue = 'Scale',
    palette = ['blue', 'orange'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of ONT Reads on Number of Contigs')
plt.axhline(0, color="black")
plt.show
#####################################################exp3 16S
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex3,
    x = "Tool",
    y = dvs[3],
    jitter = True,
    hue = 'Scale',
    palette = ['blue', 'orange'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of ONT Reads on 16S Region')
plt.axhline(0, color="black")
plt.show
##################################################### exp3 Runtime
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex3,
    x = "Tool",
    y = dvs[4],
    jitter = True,
    hue = 'Scale',
    palette = ['blue', 'orange'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of ONT Reads on Runtime')
plt.axhline(0, color="black")
plt.show
##################################################### exp3 Memory
plt.figure(figsize=(10, 7),facecolor='white')
sns.stripplot(
    data = ex3,
    x = "Tool",
    y = dvs[5],
    jitter = True,
    hue = 'Scale',
    palette = ['blue', 'orange'],
    dodge = True,
    edgecolor ='black',
    linewidth=0.5
)
plt.title('Effect of ONT Reads on Memory Usage')
plt.axhline(0, color="black")
plt.show
# Out:
#     Experiment Scale       Tool  Replicate  LGA90  misassemblies  contigs  \
# 0            1  High       flye          1      1              0        1
# 1            1  High       flye          2     30              9       44
# 2            1  High       flye          3     45             19       61
# 3            1   Mid       flye          1     33             12       53
# 4            1   Mid       flye          2     34              9       57
# ..         ...   ...        ...        ...    ...            ...      ...
# 67           2   Mid  BRRspades          2     73              0      141
# 68           2   Mid  BRRspades          3     73              0      144
# 69           2   Low  BRRspades          1     74              0      145
# 70           2   Low  BRRspades          2     76              0      148
# 71           2   Low  BRRspades          3     75              0      146
#
#     16Sident  Unnamed: 8  Unnamed: 9  ...  Unnamed: 28  Unnamed: 29  \
# 0      99.06         NaN         NaN  ...          NaN          NaN
# 1      99.12         NaN         NaN  ...          NaN          NaN
# 2      99.13         NaN         NaN  ...          NaN          NaN
# 3      98.99         NaN         NaN  ...          NaN          NaN
# 4      99.10         NaN         NaN  ...          NaN          NaN
# ..       ...         ...         ...  ...          ...          ...
# 67     99.31         NaN         NaN  ...          NaN          NaN
# 68     99.31         NaN         NaN  ...          NaN          NaN
# 69     99.31         NaN         NaN  ...          NaN          NaN
# 70     98.83         NaN         NaN  ...          NaN          NaN
# 71     99.31         NaN         NaN  ...          NaN          NaN
#
#     Unnamed: 30  Unnamed: 31  Unnamed: 32  Unnamed: 33  Unnamed: 34  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 67          NaN          NaN          NaN          NaN          NaN
# 68          NaN          NaN          NaN          NaN          NaN
# 69          NaN          NaN          NaN          NaN          NaN
# 70          NaN          NaN          NaN          NaN          NaN
# 71          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 35  Unnamed: 36  Unnamed: 37
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# ..          ...          ...          ...
# 67          NaN          NaN          NaN
# 68          NaN          NaN          NaN
# 69          NaN          NaN          NaN
# 70          NaN          NaN          NaN
# 71          NaN          NaN          NaN
#
# [72 rows x 38 columns]
# <function matplotlib.pyplot.show(close=None, block=None)>
