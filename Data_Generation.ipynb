# %% [markdown]
# SIMULATED DATA:
# Simulated reads were generated using Escherichia coli BL21 reference genome.
# Short-read simulation done via ART.
# Long-read simulation done via badread.
# Each experiment was repeated three times for three replicates.
# Short-read mean fragment length always set to 200bp in length.
# Long-read mean fragment length always set to 7000bp, 400bp stdev. (See experiment 3).
# All assembled at 32 cores.

# %% [markdown]
# EXPERIMENT 1:
# Simulating read quality (accuracy) at varying levels (high, low, and mid).
# Short-reads generated at MSv3 (high quality), HS20 (moderate quality), and GAIIx (poor quality), respectively.
# Long-reads generated at (identity%, stdev) 95,2.5 , 73,10 , and 50,15 respectively.
# Short-read coverage always set to 50x.
# Long-read coverage always set to 100x.

# %% [markdown]
# HIGH:

# %% [markdown]
# Short-reads:

# %% [markdown]
# -ss Quality Model, -i reference genome, -p paired end reads, -l length, -f coverage, -m mean average length, -s stdev, -o output file

# %%
art_illumina -ss MSv3 -i referenceg/BL21.fasta -p -l 200 -f 50 -m 300 -s 3 -o bench_proj/ART/exp1high/rep1_

# %% [markdown]
# Long-reads (split into multiple jobs to reduce CPU load and consequently runtime):

# %% [markdown]
# --reference reference genome, --quantity coverage, --length read length --error_model error model

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > d.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > e.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > f.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > g.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > h.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > i.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > j.fastq & wait & cat a.fastq b.fastq c.fastq d.fastq e.fastq f.fastq g.fastq h.fastq i.fastq j.fastq > bench_proj/badread/exp1high/rep1.fastq

# %% [markdown]
# MID:

# %% [markdown]
# Short-reads:

# %%
art_illumina -ss HS20 -i referenceg/BL21.fasta -p -l 200 -f 50 -m 300 -s 3 -o bench_proj/ART/exp1mid/rep1_

# %% [markdown]
# Long-reads:

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > d.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > e.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > f.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > g.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > h.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > i.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 73,10 --length 7000,400 --error_model nanopore2023 > j.fastq & wait & cat a.fastq b.fastq c.fastq d.fastq e.fastq f.fastq g.fastq h.fastq i.fastq j.fastq > bench_proj/badread/exp1mid/rep1.fastq

# %% [markdown]
# LOW:

# %% [markdown]
# Short-reads:

# %%
art_illumina -ss GA2 -i referenceg/BL21.fasta -p -l 100 -f 50 -m 300 -s 3 -o bench_proj/ART/exp1low/rep1_

# %% [markdown]
# Long-reads:

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > d.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > e.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > f.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > g.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > h.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > i.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --identity 50,15 --length 7000,400 --error_model nanopore2023 > j.fastq & wait & cat a.fastq b.fastq c.fastq d.fastq e.fastq f.fastq g.fastq h.fastq i.fastq j.fastq > bench_proj/badread/exp1low/rep1.fastq

# %% [markdown]
# ASSEMBLY GENERATION:
# Each assembly was generated using each respective quality tier. Ex: Tool assembled using exp1mid short reads replicate 3, and exp1mid long read replicate 3.
# NOTE: Each tool only shows one replicate generation to save space. Assemblies were generated for each tier (High, Mid, or Low) and for each replicate per tier (1, 2, 3). Only folder location differs in code.

# %% [markdown]
# UNICYCLER:

# %% [markdown]
# --verbose time and space complexity -1 first short read -2 second short read -l long read -t threads -o output file

# %%
/usr/bin/time --verbose unicycler -1 bench_proj/ART/exp1/rep1_1.fq -2 bench_proj/ART/exp1high/rep1_2.fq -l bench_proj/badread/exp1high/rep1.fastq -t 32 -o bench_proj/unicycler/exp1high/rep1

# %% [markdown]
# FLYE:

# %% [markdown]
# --nano-raw read type and file specification --genome-size size of genome --out-dir output filepath

# %%
/usr/bin/time --verbose flye --nano-raw bench_proj/badread/exp1high/rep1.fastq --genome-size 4.7m --out-dir bench_proj/flye/exp1high/rep1

# %% [markdown]
# SPADES

# %% [markdown]
# -1 first short read -2 second short read --nanopore long read type and file -t threads -o output file

# %%
/usr/bin/time --verbose spades.py -1 bench_proj/ART/exp1high/rep1_1.fq -2 bench_proj/ART/exp1high/rep1_2.fq --nanopore bench_proj/badread/exp1high/rep1.fastq -t 32 -o bench_proj/spades/exp1high/rep1

# %% [markdown]
# EXPERIMENT 2:
# Simulating read coverage at varying levels (high, mid, low).
# Short-reads generated at 70x, 35x, and 17x, respectively.
# Long-reads generated at 100x, 50x, and 15x, respectively.
# Short-reads always set to MSv3.
# Long-reads always set to 95, 2.5 (%identity, stdev)

# %% [markdown]
# HIGH:

# %% [markdown]
# Short-reads:

# %%
art_illumina -ss MSv3 -i referenceg/BL21.fasta -p -l 200 -f 70 -m 300 -s 3 -o bench_proj/ART/exp2high/rep1_

# %% [markdown]
# Long-reads:

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > d.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > e.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > f.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > g.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > h.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > i.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > j.fastq & wait & cat a.fastq b.fastq c.fastq d.fastq e.fastq f.fastq g.fastq h.fastq i.fastq j.fastq > bench_proj/badread/exp2high/rep1.fastq

# %% [markdown]
# MID:

# %% [markdown]
# Short-reads:

# %%
art_illumina -ss MSv3 -i referenceg/BL21.fasta -p -l 200 -f 35 -m 300 -s 3 -o bench_proj/ART/exp2mid/rep1_

# %% [markdown]
# Long-reads:

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > d.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > e.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > f.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > g.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > h.fastq badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > i.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > j.fastq & wait & cat a.fastq b.fastq c.fastq d.fastq e.fastq f.fastq g.fastq h.fastq i.fastq j.fastq > bench_proj/badread/exp2mid/rep1.fastq

# %% [markdown]
# LOW:

# %% [markdown]
# Short-reads:

# %%
art_illumina -ss MSv3 -i referenceg/BL21.fasta -p -l 100 -f 17 -m 300 -s 3 -o bench_proj/ART/exp2low/rep1_

# %% [markdown]
# Long-reads:

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > d.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 10x --length 7000,400 --error_model nanopore2023 > e.fastq & wait & cat a.fastq b.fastq c.fastq d.fastq e.fastq > bench_proj/badread/exp2low/rep1.fastq

# %% [markdown]
# ASSEMBLY GENERATION:
# Each assembly was generated using each respective quality tier. Ex: Tool assembled using exp2mid short reads replicate 3, and exp2mid long read replicate 3.
# NOTE: Each tool only shows one replicate generation to save space. Assemblies were generated for each tier (High, Mid, or Low) and for each replicate per tier (1, 2, 3). Only folder location differs in code.

# %% [markdown]
# UNICYCLER:

# %%
/usr/bin/time --verbose unicycler -1 bench_proj/ART/exp2/rep1_1.fq -2 bench_proj/ART/exp2high/rep1_2.fq -l bench_proj/badread/exp2high/rep1.fastq -t 32 -o bench_proj/unicycler/exp21high/rep1

# %% [markdown]
# FLYE:

# %%
/usr/bin/time --verbose flye --nano-raw bench_proj/badread/exp2high/rep1.fastq --genome-size 4.7m --out-dir bench_proj/flye/exp2high/rep1

# %% [markdown]
# SPADES:

# %%
/usr/bin/time --verbose spades.py -1 bench_proj/ART/exp2high/rep1_1.fq -2 bench_proj/ART/exp2high/rep1_2.fq --nanopore bench_proj/badread/exp2high/rep1.fastq -t 32 -o bench_proj/spades/exp2high/rep1

# %% [markdown]
# EXPERIMENT 3:
# Simulating Oxford-Nanopore long reads in 2018 and 2024 based on publications around those times. Testing the effect of long-read quality improving over time.
# 2018 long reads were simulated at 85% identity and 9600 average read length (reads were longer and less accurate) with a coverage of 30x.
# 2024 long reads were simulated at 99% identity and 6000 average read length with a coverage of 40x.

# %% [markdown]
# 2018:

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 85,5 --length 9600,600 --error_model nanopore2018 > a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 85,5  --length 9600,600 --error_model nanopore2018 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 85,5 --length 9600,600 --error_model nanopore2018 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 85,5 --length 9600,600 --error_model nanopore2018 > d.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 85,5 --length 9600,600 --error_model nanopore2018 > e.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 85,5 --length 9600,600 --error_model nanopore2018 > f.fastq & wait & cat a.fastq b.fastq c.fastq d.fastq e.fastq f.fastq > bench_proj/badread/exp3/2018/rep1.fastq

# %% [markdown]
# 2024:

# %%
badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 99,1 --length 6000,1200 --error_model nanopore2023> a.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 99,1  --length 6000,1200 --error_model nanopore2023 > b.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 99,1 --length 6000,1200 --error_model nanopore2023 > c.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 99,1 --length 6000,1200 --error_model nanopore2023 > d.fastq & badread simulate –reference/referenceg/BL21.fasta --quantity 5x --identity 99,1 --length 6000,1200 --error_model nanopore2023 > e.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 99,1 --length 6000,1200 --error_model nanopore2023 > f.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 99,1 --length 6000,1200 --error_model nanopore2023 > g.fastq & badread simulate --reference referenceg/BL21.fasta --quantity 5x --identity 99,1 --length 6000,1200 --error_model nanopore2023 > h.fastq & wait && cat a.fastq b.fastq c.fastq d.fastq e.fastq f.fastq g.fastq h.fastq > bench_proj/badread/exp3/2024/rep1.fastq

# %% [markdown]
# ASSEMBLY GENERATION: Hybrid assemblies were generated using simulated ART short reads experiment 2 low, replicate 1 to test the effect of the long reads on assembly accuracy.
# NOTE: Each tool only shows one replicate generation to save space. Assemblies were generated for each tier (2018 or 2024) and for each replicate per tier (1, 2, 3). Only folder location differs in further code.

# %% [markdown]
# UNICYCLER:

# %%
/usr/bin/time --verbose unicycler -1 bench_proj/ART/exp2low/rep1_1.fq -2 bench_proj/ART/exp2low/rep1_2.fq -l bench_proj/badread/exp3/2018/rep1.fastq -t 32 -o bench_proj/unicycler/exp3/2018/rep1

# %% [markdown]
# FLYE:

# %%
/usr/bin/time --verbose flye --nano-raw bench_proj/badread/exp3/2018/rep1.fastq --genome-size 4.7m -t 32 --out-dir bench_proj/flye/exp3/2018/rep1

# %% [markdown]
# SPADES:

# %%
/usr/bin/time --verbose spades.py -1 bench_proj/ART/exp2low/rep1_1.fq -2 bench_proj/ART/exp2low/rep1_2.fq --nanopore bench_proj/badread/exp3/2018/rep1.fastq -t 32 -o bench_proj/spades/exp3/2018/rep1

# %% [markdown]
# QUAST: Assembly accuracy was measured with QUAST.

# %%
quast.py flye/exp1high/rep1/flyeE1H1.fasta flye/exp1high/rep2/flyeE1H2.fasta flye/exp1high/rep3/flyeE1H3.fasta flye/exp1mid/rep1/flyeE1M1.fasta flye/exp1mid/rep2/flyeE1M2.fasta flye/exp1mid/rep3/flyeE1M3.fasta flye/exp1low/rep1/flyeE1L1.fasta flye/exp1low/rep2/flyeE1L2.fasta flye/exp1low/rep3/flyeE1L3.fasta flye/exp2high/rep1/flyeE2H1.fasta flye/exp2high/rep2/flyeE2H2.fasta flye/exp2high/rep3/flyeE2H3.fasta flye/exp2mid/rep1/flyeE2M1.fasta flye/exp2mid/rep2/flyeE2M2.fasta flye/exp2mid/rep3/flyeE2M3.fasta flye/exp2low/rep1/flyeE2L1.fasta flye/exp2low/rep2/flyeE2L2.fasta flye/exp2low/rep3/flyeE2L3.fasta unicycler/exp1high/rep1/uniE1H1.fasta unicycler/exp1high/rep2/uniE1H2.fasta unicycler/exp1high/rep3/uniE1H3.fasta unicycler/exp1mid/rep1/uniE1M1.fasta unicycler/exp1mid/rep2/uniE1M2.fasta unicycler/exp1mid/rep3/uniE1M3.fasta unicycler/exp1low/rep1/uniE1L1.fasta unicycler/exp1low/rep2/uniE1L2.fasta unicycler/exp1low/rep3/uniE1L3.fasta unicycler/exp2high/rep1/uniE2H1.fasta unicycler/exp2high/rep2/uniE2H2.fasta unicycler/exp2high/rep3/uniE2H3.fasta unicycler/exp2mid/rep1/uniE2M1.fasta unicycler/exp2mid/rep2/uniE2M2.fasta unicycler/exp2mid/rep3/uniE2M3.fasta unicycler/exp2low/rep1/uniE2L1.fasta unicycler/exp2low/rep2/uniE2L2.fasta unicycler/exp2low/rep3/uniE2L3.fasta spades/exp1high/rep1/spadesE1H1.fasta spades/exp1high/rep1/BRRspadesE1H1.fasta spades/exp1high/rep2/spadesE1H2.fasta spades/exp1high/rep2/BRRspadesE1H2.fasta spades/exp1high/rep3/spadesE1H3.fasta spades/exp1high/rep3/BRRspadesE1H3.fasta spades/exp1mid/rep1/spadesE1M1.fasta spades/exp1mid/rep1/BRRspadesE1M1.fasta spades/exp1mid/rep2/spadesE1M2.fasta spades/exp1mid/rep2/BRRspadesE1M2.fasta spades/exp1mid/rep3/spadesE1M3.fasta spades/exp1mid/rep3/BRRspadesE1M3.fasta spades/exp1low/rep1/spadesE1L1.fasta spades/exp1low/rep1/BRRspadesE1L1.fasta spades/exp1low/rep2/spadesE1L2.fasta spades/exp1low/rep2/BRRspadesE1L2.fasta spades/exp1low/rep3/spadesE1L3.fasta spades/exp1low/rep3/BRRspadesE1L3.fasta spades/exp2high/rep1/spadesE2H1.fasta spades/exp2high/rep1/BRRspadesE2H1.fasta spades/exp2high/rep2/spadesE2H2.fasta spades/exp2high/rep2/BRRspadesE2H2.fasta spades/exp2high/rep3/spadesE2H3.fasta spades/exp2high/rep3/BRRspadesE2H3.fasta spades/exp2mid/rep1/spadesE2M1.fasta spades/exp2mid/rep1/BRRspadesE2M1.fasta spades/exp2mid/rep2/spadesE2M2.fasta spades/exp2mid/rep2/BRRspadesE2M2.fasta spades/exp2mid/rep3/spadesE2M3.fasta spades/exp2mid/rep3/BRRspadesE2M3.fasta spades/exp2low/rep1/spadesE2L1.fasta spades/exp2low/rep1/BRRspadesE2L1.fasta spades/exp2low/rep2/spadesE1L2.fasta spades/exp2low/rep2/BRRspadesE2L2.fasta spades/exp2low/rep3/spadesE2L3.fasta spades/exp2low/rep3/BRRspadesE2L3.fasta flye/exp3/2018/rep1/flyeE3_18_1.fasta flye/exp3/2018/rep2/flyeE3_18_2.fasta flye/exp3/2018/rep3/flyeE3_18_3.fasta flye/exp3/2024/rep1/flyeE3_24_1.fasta flye/exp3/2024/rep2/flyeE3_24_2.fasta flye/exp3/2024/rep3/flyeE3_24_3.fasta unicycler/exp3/2018/rep1/uniE3_18_1.fasta unicycler/exp3/2018/rep2/uniE3_18_2.fasta unicycler/exp3/2018/rep3/uniE3_18_3.fasta unicycler/exp3/2024/rep1/uniE3_24_1.fasta unicycler/exp3/2024/rep2/uniE3_24_2.fasta unicycler/exp3/2024/rep3/uniE3_24_3.fasta spades/exp3/2018/rep1/spadesE3_18_1.fasta spades/exp3/2018/rep1/BRRspadesE3_18_1.fasta spades/exp3/2018/rep2/spadesE3_18_2.fasta spades/exp3/2018/rep2/BRRspadesE3_18_2.fasta spades/exp3/2018/rep3/spadesE3_18_3.fasta spades/exp3/2018/rep3/BRRspadesE3_18_3.fasta spades/exp3/2024/rep1/spadesE3_24_1.fasta spades/exp3/2024/rep1/BRRspadesE3_24_1.fasta spades/exp3/2024/rep2/spadesE3_24_2.fasta spades/exp3/2024/rep2/BRRspadesE3_24_1.fasta spades/exp3/2024/rep3/spadesE3_24_3.fasta spades/exp3/2024/rep3/BRRspadesE3_24_1.fasta -r BL21.fasta -o QUAST/allofit

# %% [markdown]
# BLAST: 16S Assembly accuracy was measured with BLAST.

# %%
for i in flye/exp1high/rep1/flyeE1H1.fasta flye/exp1high/rep2/flyeE1H2.fasta flye/exp1high/rep3/flyeE1H3.fasta flye/exp1mid/rep1/flyeE1M1.fasta flye/exp1mid/rep2/flyeE1M2.fasta flye/exp1mid/rep3/flyeE1M3.fasta flye/exp1low/rep1/flyeE1L1.fasta flye/exp1low/rep2/flyeE1L2.fasta flye/exp1low/rep3/flyeE1L3.fasta flye/exp2high/rep1/flyeE2H1.fasta flye/exp2high/rep2/flyeE2H2.fasta flye/exp2high/rep3/flyeE2H3.fasta flye/exp2mid/rep1/flyeE2M1.fasta flye/exp2mid/rep2/flyeE2M2.fasta flye/exp2mid/rep3/flyeE2M3.fasta flye/exp2low/rep1/flyeE2L1.fasta flye/exp2low/rep2/flyeE2L2.fasta flye/exp2low/rep3/flyeE2L3.fasta unicycler/exp1high/rep1/uniE1H1.fasta unicycler/exp1high/rep2/uniE1H2.fasta unicycler/exp1high/rep3/uniE1H3.fasta unicycler/exp1mid/rep1/uniE1M1.fasta unicycler/exp1mid/rep2/uniE1M2.fasta unicycler/exp1mid/rep3/uniE1M3.fasta unicycler/exp1low/rep1/uniE1L1.fasta unicycler/exp1low/rep2/uniE1L2.fasta unicycler/exp1low/rep3/uniE1L3.fasta unicycler/exp2high/rep1/uniE2H1.fasta unicycler/exp2high/rep2/uniE2H2.fasta unicycler/exp2high/rep3/uniE2H3.fasta unicycler/exp2mid/rep1/uniE2M1.fasta unicycler/exp2mid/rep2/uniE2M2.fasta unicycler/exp2mid/rep3/uniE2M3.fasta unicycler/exp2low/rep1/uniE2L1.fasta unicycler/exp2low/rep2/uniE2L2.fasta unicycler/exp2low/rep3/uniE2L3.fasta spades/exp1high/rep1/spadesE1H1.fasta spades/exp1high/rep1/BRRspadesE1H1.fasta spades/exp1high/rep2/spadesE1H2.fasta spades/exp1high/rep2/BRRspadesE1H2.fasta spades/exp1high/rep3/spadesE1H3.fasta spades/exp1high/rep3/BRRspadesE1H3.fasta spades/exp1mid/rep1/spadesE1M1.fasta spades/exp1mid/rep1/BRRspadesE1M1.fasta spades/exp1mid/rep2/spadesE1M2.fasta spades/exp1mid/rep2/BRRspadesE1M2.fasta spades/exp1mid/rep3/spadesE1M3.fasta spades/exp1mid/rep3/BRRspadesE1M3.fasta spades/exp1low/rep1/spadesE1L1.fasta spades/exp1low/rep1/BRRspadesE1L1.fasta spades/exp1low/rep2/spadesE1L2.fasta spades/exp1low/rep2/BRRspadesE1L2.fasta spades/exp1low/rep3/spadesE1L3.fasta spades/exp1low/rep3/BRRspadesE1L3.fasta spades/exp2high/rep1/spadesE2H1.fasta spades/exp2high/rep1/BRRspadesE2H1.fasta spades/exp2high/rep2/spadesE2H2.fasta spades/exp2high/rep2/BRRspadesE2H2.fasta spades/exp2high/rep3/spadesE2H3.fasta spades/exp2high/rep3/BRRspadesE2H3.fasta spades/exp2mid/rep1/spadesE2M1.fasta spades/exp2mid/rep1/BRRspadesE2M1.fasta spades/exp2mid/rep2/spadesE2M2.fasta spades/exp2mid/rep2/BRRspadesE2M2.fasta spades/exp2mid/rep3/spadesE2M3.fasta spades/exp2mid/rep3/BRRspadesE2M3.fasta spades/exp2low/rep1/spadesE2L1.fasta spades/exp2low/rep1/BRRspadesE2L1.fasta spades/exp2low/rep2/spadesE2L2.fasta spades/exp2low/rep2/BRRspadesE2L2.fasta spades/exp2low/rep3/spadesE2L3.fasta spades/exp2low/rep3/BRRspadesE2L3.fasta flye/exp3/2018/rep1/flyeE3_18_1.fasta flye/exp3/2018/rep2/flyeE3_18_2.fasta flye/exp3/2018/rep3/flyeE3_18_3.fasta flye/exp3/2024/rep1/flyeE3_24_1.fasta flye/exp3/2024/rep2/flyeE3_24_2.fasta flye/exp3/2024/rep3/flyeE3_24_3.fasta unicycler/exp3/2018/rep1/uniE3_18_1.fasta unicycler/exp3/2018/rep2/uniE3_18_2.fasta unicycler/exp3/2018/rep3/uniE3_18_3.fasta unicycler/exp3/2024/rep1/uniE3_24_1.fasta unicycler/exp3/2024/rep2/uniE3_24_2.fasta unicycler/exp3/2024/rep3/uniE3_24_3.fasta spades/exp3/2018/rep1/spadesE3_18_1.fasta spades/exp3/2018/rep1/BRRspadesE3_18_1.fasta spades/exp3/2018/rep2/spadesE3_18_2.fasta spades/exp3/2018/rep2/BRRspadesE3_18_2.fasta spades/exp3/2018/rep3/spadesE3_18_3.fasta spades/exp3/2018/rep3/BRRspadesE3_18_3.fasta spades/exp3/2024/rep1/spadesE3_24_1.fastaspades/exp3/2024/rep1/BRRspadesE3_24_1.fasta spades/exp3/2024/rep2/spadesE3_24_2.fasta spades/exp3/2024/rep2/BRRspadesE3_24_1.fasta spades/exp3/2024/rep3/spadesE3_24_3.fasta spades/exp3/2024/rep3/BRRspadesE3_24_1.fasta; do     prefix=$(basename "$i" .fasta);     sed "s/^>/>${prefix}_/" "$i" >> expB.fasta; done

# %% [markdown]
# Generate a concatenated fasta file where each assembly is denoted with its respective file name as the header.

# %%
makeblastdb -in expB.fasta -dbtype nucl -out assembly3B

# %% [markdown]
# Make a BLAST database using this fasta file before executing the blast

# %%
blastn -query BL21_16S.fasta -db assemblydb -outfmt "6 qseqid sseqid pident length mismatch gapopen qstart qend sstart send evalue bitscore" -out blast3_simulated.txt

# %% [markdown]
# Call BLAST command query to generate metrics on the 16S region of E. coli BL21 using its reference 16S region. Tried to make each column header its respective name but did not work.

# %%
tr '\t' ',' < blast3_simulated.txt > blast3_simulated.csv

# %% [markdown]
# Edited column headers manuallyin Excel after converting .txt to .csv
